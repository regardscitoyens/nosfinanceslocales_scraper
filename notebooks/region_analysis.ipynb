# %% [markdown]
# ## Analyse des finances des régions sur 2008-2012

# %%
import pandas as pd
import os
curdir = os.path.abspath('./..')

# %%
filenames = [os.path.join(curdir, 'scraped_data', 'regions_%s.csv'%year) for year in range(2008,2013)]

# %%
df = pd.concat([pd.read_csv(filename) for filename in filenames])
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130 entries, 0 to 25
# Data columns (total 60 columns):
# land_property_tax_cuts_on_deliberation               52  non-null values
# mandatory_contributions_and_stakes                   130  non-null values
# property_tax_rate                                    78  non-null values
# subsidies_and_contingents                            130  non-null values
# financing_capacity                                   130  non-null values
# individual_aids                                      130  non-null values
# operating_revenues                                   130  non-null values
# business_tax_value                                   52  non-null values
# property_tax_cuts_on_deliberation                    52  non-null values
# property_tax_value                                   78  non-null values
# land_property_tax_basis                              78  non-null values
# received_subsidies                                   130  non-null values
# business_network_tax_value                           52  non-null values
# net_profit                                           130  non-null values
# business_profit_contribution_basis                   0  non-null values
# business_network_tax_rate                            0  non-null values
# thirdparty_balance                                   130  non-null values
# business_tax_cuts_on_deliberation                    26  non-null values
# paid_subsidies                                       130  non-null values
# business_tax_rate                                    52  non-null values
# population                                           130  non-null values
# name                                                 130  non-null values
# operating_real_revenues                              130  non-null values
# business_profit_contribution_cuts_on_deliberation    52  non-null values
# business_profit_contribution_value                   52  non-null values
# insee_code                                           130  non-null values
# direct_tax                                           130  non-null values
# zone_type                                            130  non-null values
# refund_tax                                           130  non-null values
# land_property_tax_value                              78  non-null values
# investments_direct_costs                             130  non-null values
# staff_costs                                          130  non-null values
# investment_ressources                                130  non-null values
# financial_costs                                      130  non-null values
# subsidies                                            130  non-null values
# year                                                 130  non-null values
# fctva                                                130  non-null values
# operating_costs                                      130  non-null values
# debt_repayments                                      130  non-null values
# sold_fixed_assets                                    130  non-null values
# purchases_and_external_costs                         130  non-null values
# residual_financing_capacity                          130  non-null values
# training_and_learning_allocation                     130  non-null values
# debt_at_end_year                                     130  non-null values
# business_network_tax_cuts_on_deliberation            0  non-null values
# global_profit                                        130  non-null values
# business_tax_basis                                   52  non-null values
# property_tax_basis                                   78  non-null values
# business_profit_contribution_rate                    0  non-null values
# tipp                                                 130  non-null values
# operating_real_costs                                 130  non-null values
# other_tax                                            130  non-null values
# allocation                                           130  non-null values
# loans                                                130  non-null values
# realignment                                          130  non-null values
# investments_usage                                    130  non-null values
# land_property_tax_rate                               75  non-null values
# url                                                  130  non-null values
# debt_annual_costs                                    130  non-null values
# business_network_tax_basis                           0  non-null values
# dtypes: float64(54), int64(3), object(3)

# %%
dfgp = df.groupby(['insee_code', 'year']).first()
dfmean = df.groupby('year').mean()
population_by_year = df.groupby('year')['population'].sum()

# %%
def plot_value(value, by_person=True):
    fig, axes = plt.subplots(figsize=(12,6))
    axes.set_title('%s by person from 2008 to 2012'%value)
    
    for reg in dfgp.index.get_level_values(0).unique()[:5]:
        years = dfgp.index.get_level_values(1).unique()
        if by_person:
            data = dfgp[value][reg]/dfgp['population'][reg]
        else:
            data = dfgp[value][reg]
        axes.plot(years, data.tolist(), label=dfgp['name'][reg][years[0]])
    if by_person:
        mean = dfmean[value]/population_by_year
    else:
        mean = dfmean[value]
    axes.plot(years, mean.tolist(), label='mean')
    axes.legend(loc='best');

# %%
plot_value('tipp')
plot_value('debt_annual_costs')

# %%
plot_value('staff_costs', by_person=False)
